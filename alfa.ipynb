# %%
import pandas as pd
import numpy as np

# %%
# Read data from files 

# Load the dataset
file_path = 'labeled_lyrics_cleaned.csv'
lyrics_data = pd.read_csv(file_path)

file_path = 'SpotifyFeatures.csv'
track_data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
lyrics_data.head()
# Out:
#    col_0        artist                                                seq  \
# 0      0  Elijah Blake  No, no\nI ain't ever trapped out the bando\nBu...
# 1      1  Elijah Blake  The drinks go down and smoke goes up, I feel m...
# 2      2  Elijah Blake  She don't live on planet Earth no more\nShe fo...
# 3      3  Elijah Blake  Trippin' off that Grigio, mobbin', lights low\...
# 4      4  Elijah Blake  I see a midnight panther, so gallant and so br...
#
#                  song  label
# 0            Everyday  0.626
# 1    Live Till We Die  0.630
# 2       The Otherside  0.240
# 3               Pinot  0.536
# 4  Shadows & Diamonds  0.371

# %%
track_data.head()

lyrics_merge = pd.merge(lyrics_data, track_data, how='inner', left_on=['artist', 'song'], right_on=['artist_name', 'track_name'])

lyrics_merge.head()
# Out:
#    col_0              artist  \
# 0    108  Elizabeth Mitchell
# 1    109  Elizabeth Mitchell
# 2    111  Elizabeth Mitchell
# 3    116  Elizabeth Mitchell
# 4    165           Ella Eyre
#
#                                                  seq  \
# 0  Little bird, little bird\nFly through my windo...
# 1  I've got a friend in Baltimore, little Liza Ja...
# 2  Who's my pretty baby\nWho's my pretty little b...
# 3  Go to sleep, go to sleep\nGo to sleep you litt...
# 4  Not a word, from your lips\nYou just took for ...
#
#                                     song  label             genre  \
# 0               Little Bird, Little Bird  0.641              Folk
# 1                       Little Liza Jane  0.701  Children's Music
# 2                   Who's My Pretty Baby  0.664              Folk
# 3                              Sleep Eye  0.793              Folk
# 4  We Don't Have To Take Our Clothes Off  0.332               Pop
#
#           artist_name                             track_name  \
# 0  Elizabeth Mitchell               Little Bird, Little Bird
# 1  Elizabeth Mitchell                       Little Liza Jane
# 2  Elizabeth Mitchell                   Who's My Pretty Baby
# 3  Elizabeth Mitchell                              Sleep Eye
# 4           Ella Eyre  We Don't Have To Take Our Clothes Off
#
#                  track_id  popularity  ...  energy  instrumentalness  key  \
# 0  5mdDzJBkQ7Gz7ePDCB397w          41  ...   0.223          0.007110    C
# 1  1S8HTkZ8KmXM5wCFIGtJ42           5  ...   0.227          0.000000    B
# 2  2mZxNdZTN7Uuhv5W4IwzC8          39  ...   0.257          0.072400    E
# 3  14FcnjzhhpjLBg8UnjbtGp          39  ...   0.211          0.473000    D
# 4  48wSJ6NhMFYYB6LjdnPNjM          65  ...   0.231          0.000004    C
#
#    liveness  loudness   mode  speechiness    tempo time_signature  valence
# 0     0.121   -17.700  Minor       0.3670  175.357            4/4    0.641
# 1     0.118   -14.411  Minor       0.1850  105.772            4/4    0.738
# 2     0.333   -15.539  Minor       0.0312  107.803            4/4    0.664
# 3     0.073   -17.952  Minor       0.4920  176.193            4/4    0.793
# 4     0.111    -6.316  Minor       0.0334   96.729            3/4    0.332
#
# [5 rows x 23 columns]

# %%
# remove unwanted columns
lyrics_merge.drop(columns=['artist', 'song', 'col_0', 'label'], inplace=True)

# %%
lyrics_merge['seq'] = lyrics_merge['seq'].replace('¶', ' ', regex=True)

# Add sentence length
lyrics_merge['lyrics_length'] = lyrics_merge['seq'].apply(lambda x: len(x.split()))

# Drop lyrics column
lyrics_merge.drop(columns=['seq'], inplace=True)

lyrics_merge.head()
# Out:
#               genre         artist_name  \
# 0              Folk  Elizabeth Mitchell
# 1  Children's Music  Elizabeth Mitchell
# 2              Folk  Elizabeth Mitchell
# 3              Folk  Elizabeth Mitchell
# 4               Pop           Ella Eyre
#
#                               track_name                track_id  popularity  \
# 0               Little Bird, Little Bird  5mdDzJBkQ7Gz7ePDCB397w          41
# 1                       Little Liza Jane  1S8HTkZ8KmXM5wCFIGtJ42           5
# 2                   Who's My Pretty Baby  2mZxNdZTN7Uuhv5W4IwzC8          39
# 3                              Sleep Eye  14FcnjzhhpjLBg8UnjbtGp          39
# 4  We Don't Have To Take Our Clothes Off  48wSJ6NhMFYYB6LjdnPNjM          65
#
#    acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 0         0.960         0.487       148213   0.223          0.007110   C
# 1         0.789         0.855       145947   0.227          0.000000   B
# 2         0.899         0.728       113013   0.257          0.072400   E
# 3         0.960         0.595       139373   0.211          0.473000   D
# 4         0.953         0.572       230711   0.231          0.000004   C
#
#    liveness  loudness   mode  speechiness    tempo time_signature  valence  \
# 0     0.121   -17.700  Minor       0.3670  175.357            4/4    0.641
# 1     0.118   -14.411  Minor       0.1850  105.772            4/4    0.738
# 2     0.333   -15.539  Minor       0.0312  107.803            4/4    0.664
# 3     0.073   -17.952  Minor       0.4920  176.193            4/4    0.793
# 4     0.111    -6.316  Minor       0.0334   96.729            3/4    0.332
#
#    lyrics_length
# 0            192
# 1            218
# 2            116
# 3            183
# 4            290

# %%
# Function to convert pitch to number
def pitch_to_number(pitch):
    pitch_map = {
        'C': 0,
        'C#': 1, 'Db': 1,
        'D': 2,
        'D#': 3, 'Eb': 3,
        'E': 4, 'Fb': 4,
        'E#': 5, 'F': 5,
        'F#': 6, 'Gb': 6,
        'G': 7,
        'G#': 8, 'Ab': 8,
        'A': 9,
        'A#': 10, 'Bb': 10,
        'B': 11, 'Cb': 11
    }
    return pitch_map.get(pitch, None)

# Replace the pitch column with its numeric representation
# Assuming the column name in your DataFrame that contains pitch values is 'pitch_column'
lyrics_merge['key'] = lyrics_merge['key'].apply(pitch_to_number)

# %%
# Convert the mode column to 1 for major and 0 for minor
lyrics_merge['mode'] = lyrics_merge['mode'].replace("Minor", 0)
lyrics_merge['mode'] = lyrics_merge['mode'].replace("Major", 1)

lyrics_merge.head()
# Out:
#               genre         artist_name  \
# 0              Folk  Elizabeth Mitchell
# 1  Children's Music  Elizabeth Mitchell
# 2              Folk  Elizabeth Mitchell
# 3              Folk  Elizabeth Mitchell
# 4               Pop           Ella Eyre
#
#                               track_name                track_id  popularity  \
# 0               Little Bird, Little Bird  5mdDzJBkQ7Gz7ePDCB397w          41
# 1                       Little Liza Jane  1S8HTkZ8KmXM5wCFIGtJ42           5
# 2                   Who's My Pretty Baby  2mZxNdZTN7Uuhv5W4IwzC8          39
# 3                              Sleep Eye  14FcnjzhhpjLBg8UnjbtGp          39
# 4  We Don't Have To Take Our Clothes Off  48wSJ6NhMFYYB6LjdnPNjM          65
#
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0         0.960         0.487       148213   0.223          0.007110    0
# 1         0.789         0.855       145947   0.227          0.000000   11
# 2         0.899         0.728       113013   0.257          0.072400    4
# 3         0.960         0.595       139373   0.211          0.473000    2
# 4         0.953         0.572       230711   0.231          0.000004    0
#
#    liveness  loudness  mode  speechiness    tempo time_signature  valence  \
# 0     0.121   -17.700     0       0.3670  175.357            4/4    0.641
# 1     0.118   -14.411     0       0.1850  105.772            4/4    0.738
# 2     0.333   -15.539     0       0.0312  107.803            4/4    0.664
# 3     0.073   -17.952     0       0.4920  176.193            4/4    0.793
# 4     0.111    -6.316     0       0.0334   96.729            3/4    0.332
#
#    lyrics_length
# 0            192
# 1            218
# 2            116
# 3            183
# 4            290

# %%
# Handle outliers in the dataset
# remove song that are to long in duration songs longer than 500000 ms (500 seconds = 8.3 minutes)

lyrics_merge.head()
lyrics_merge = lyrics_merge[lyrics_merge['duration_ms'] < 500000]


# Remove unwanted columns
lyrics_merge.drop(columns=['artist_name', 'track_name', 'track_id', 'time_signature'], inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler


numerical_cols = ['acousticness', 'danceability', 'duration_ms', 'energy', 
                  'instrumentalness', 'liveness', 'loudness', 'speechiness', 
                  'tempo', 'valence', 'lyrics_length']

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Scale the numerical columns using MinMaxScaler
lyrics_merge[numerical_cols] = scaler.fit_transform(lyrics_merge[numerical_cols])

lyrics_merge.head()
# Out:
#               genre  popularity  acousticness  danceability  duration_ms  \
# 0              Folk          41      0.964824      0.467722     0.251087
# 1  Children's Music           5      0.792965      0.872429     0.246238
# 2              Folk          39      0.903517      0.732761     0.175754
# 3              Folk          39      0.964824      0.586495     0.232168
# 4               Pop          65      0.957789      0.561201     0.427646
#
#      energy  instrumentalness  key  liveness  loudness  mode  speechiness  \
# 0  0.217576          0.007263    0  0.104585  0.432811     0     0.369572
# 1  0.221609          0.000000   11  0.101515  0.535332     0     0.174440
# 2  0.251858          0.073953    4  0.321531  0.500171     0     0.009542
# 3  0.205477          0.483146    2  0.055465  0.424956     0     0.503592
# 4  0.225643          0.000004    0  0.094351  0.787662     0     0.011901
#
#       tempo   valence  lyrics_length
# 0  0.705491  0.637810       0.130912
# 1  0.348045  0.739349       0.148732
# 2  0.358478  0.661886       0.078821
# 3  0.709785  0.796922       0.124743
# 4  0.301593  0.314352       0.198081

# %%
# remove the rows with genre with less than 100 songs
lyrics_merge = lyrics_merge.groupby('genre').filter(lambda x: len(x) > 400)

print(lyrics_merge['genre'].value_counts())

# Make a datafram for each genre
country = lyrics_merge[lyrics_merge['genre'] == 'Country']
alternative = lyrics_merge[lyrics_merge['genre'] == 'Alternative']
rock = lyrics_merge[lyrics_merge['genre'] == 'Rock']
children = lyrics_merge[lyrics_merge['genre'] == 'Children’s Music']
folk = lyrics_merge[lyrics_merge['genre'] == 'Folk']
dance = lyrics_merge[lyrics_merge['genre'] == 'Dance']
blues = lyrics_merge[lyrics_merge['genre'] == 'Blues']
pop = lyrics_merge[lyrics_merge['genre'] == 'Pop']
rnb = lyrics_merge[lyrics_merge['genre'] == 'R&B']
indie = lyrics_merge[lyrics_merge['genre'] == 'Indie']
soul = lyrics_merge[lyrics_merge['genre'] == 'Soul']
rap = lyrics_merge[lyrics_merge['genre'] == 'Rap']
ska = lyrics_merge[lyrics_merge['genre'] == 'Ska']
hiphop = lyrics_merge[lyrics_merge['genre'] == 'Hip-Hop']
jazz = lyrics_merge[lyrics_merge['genre'] == 'Jazz']

list_of_genres = [country, rock, children, folk, dance, blues, rnb, indie, soul, rap, ska, hiphop, alternative, jazz]
# Out:
# genre
# Country             1280
# Alternative         1274
# Rock                1243
# Children’s Music    1198
# Folk                1115
# Dance                944
# Blues                922
# Pop                  825
# R&B                  777
# Indie                766
# Soul                 725
# Rap                  690
# Ska                  634
# Hip-Hop              532
# Jazz                 406
# Name: count, dtype: int64

# %%
for genre in list_of_genres:
    print(genre["genre"].iloc[0])
    genre.drop(columns=['genre'], inplace=True)
    print(genre.head())

dict_of_genres = {
    'country': country,
    'Alternative': alternative,
    'rock': rock,
    'children': children,
    'folk': folk,
    'dance': dance,
    'blues': blues,
    'rnb': rnb,
    'indie': indie,
    'soul': soul,
    'rap': rap,
    'ska': ska,
    'hiphop': hiphop,
    'Jazz': jazz
}
# Out:
# Country
#      popularity  acousticness  danceability  duration_ms    energy  \
# 132          44      0.056682      0.537006     0.574537  0.564424
# 250          48      0.123617      0.644782     0.292065  0.650128
# 265          46      0.123617      0.350049     0.454517  0.593664
# 268          73      0.272361      0.502914     0.361806  0.747931
# 269          42      0.037386      0.455625     0.445186  0.632987
#
#      instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 132          0.000052    3  0.088211  0.758798     1     0.010614  0.605914
# 250          0.000398    9  0.100491  0.730308     0     0.063043  0.616578
# 265          0.000001    7  0.115841  0.876407     1     0.009864  0.495323
# 268          0.000000    6  0.102538  0.881113     0     0.019513  0.564475
# 269          0.000000    6  0.103561  0.834170     1     0.005361  0.595095
#
#       valence  lyrics_length
# 132  0.099759       0.222755
# 250  0.452528       0.116518
# 265  0.134303       0.177519
# 268  0.270386       0.191227
# 269  0.263059       0.225497
# Rock
#      popularity  acousticness  danceability  duration_ms    energy  \
# 72           59      0.003456      0.078412     0.415139  0.927404
# 123          54      0.063014      0.159793     0.244153  0.967735
# 172          65      0.017285      0.703068     0.531049  0.814477
# 185          62      0.002532      0.378643     0.428549  0.810444
# 190          64      0.278391      0.369845     0.630723  0.428306
#
#      instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 72           0.000449    7  0.074396  0.817119     1     0.055538  0.820304
# 123          0.000065    4  0.496521  0.816807     1     0.081377  0.844524
# 172          0.000640    0  0.079922  0.797668     1     0.016833  0.514324
# 185          0.003851    6  0.364511  0.756367     1     0.023480  0.267633
# 190          0.000009   11  0.142448  0.695115     1     0.020585  0.286059
#
#       valence  lyrics_length
# 72   0.490212       0.169294
# 123  0.592798       0.124058
# 172  0.668167       0.210418
# 185  0.085104       0.194654
# 190  0.445200       0.135709
# Children’s Music
#      popularity  acousticness  danceability  duration_ms    energy  \
# 70           59      0.003456      0.078412     0.415139  0.927404
# 122          54      0.063014      0.159793     0.244153  0.967735
# 130          52      0.000550      0.417134     0.277711  0.966727
# 157          58      0.067939      0.645881     0.446526  0.941520
# 160          54      0.211054      0.840537     0.541292  0.487795
#
#      instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 70           0.000449    7  0.074396  0.817119     1     0.055538  0.820304
# 122          0.000065    4  0.496521  0.816807     1     0.081377  0.844524
# 130          0.000847    4  0.405444  0.832549     0     0.030020  0.335486
# 157          0.000000    2  0.073373  0.854899     1     0.402809  0.274435
# 160          0.074464    9  0.075829  0.633428     1     0.152997  0.400574
#
#       valence  lyrics_length
# 70   0.490212       0.169294
# 122  0.592798       0.124058
# 130  0.580237       0.151474
# 157  0.635717       0.434544
# 160  0.612687       0.312543
# Folk
#      popularity  acousticness  danceability  duration_ms    energy  \
# 0            41      0.964824      0.467722     0.251087  0.217576
# 2            39      0.903517      0.732761     0.175754  0.251858
# 3            39      0.964824      0.586495     0.232168  0.205477
# 53           49      0.126632      0.282965     0.334868  0.541234
# 168          65      0.017285      0.703068     0.531049  0.814477
#
#      instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 0            0.007263    0  0.104585  0.432811     0     0.369572  0.705491
# 2            0.073953    4  0.321531  0.500171     0     0.009542  0.358478
# 3            0.483146    2  0.055465  0.424956     0     0.503592  0.709785
# 53           0.000011   11  0.247851  0.772544     0     0.015117  0.213255
# 168          0.000640    0  0.079922  0.797668     1     0.016833  0.514324
#
#       valence  lyrics_length
# 0    0.637810       0.130912
# 2    0.661886       0.078821
# 3    0.796922       0.124743
# 53   0.251544       0.077450
# 168  0.668167       0.210418
# Dance
#      popularity  acousticness  danceability  duration_ms    energy  \
# 56           59      0.161808      0.784450     0.316918  0.661219
# 59           76      0.403014      0.732761     0.311241  0.411166
# 167          65      0.017285      0.703068     0.531049  0.814477
# 174          44      0.020502      0.577697     0.475033  0.965719
# 217          60      0.409045      0.621687     0.528509  0.407133
#
#      instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 56           0.000045    4  0.050143  0.833858     1     0.180873  0.513261
# 59           0.000000    8  0.043799  0.770955     1     0.044602  0.391056
# 167          0.000640    0  0.079922  0.797668     1     0.016833  0.514324
# 174          0.003023    7  0.080025  0.936473     1     0.070977  0.487017
# 217          0.000000    9  0.064163  0.689162     0     0.139059  0.189667
#
#       valence  lyrics_length
# 56   0.560348       0.225497
# 59   0.443107       0.259767
# 167  0.668167       0.210418
# 174  0.773893       0.076080
# 217  0.446247       0.424949
# Blues
#     popularity  acousticness  danceability  duration_ms    energy  \
# 5           36      0.935678      0.728362     0.284247  0.074703
# 7           40      0.856281      0.600792     0.247265  0.351677
# 9           40      0.920603      0.585395     0.308645  0.287147
# 11          50      0.975879      0.320356     0.840229  0.105657
# 13          35      0.921608      0.586495     0.381523  0.087206
#
#     instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 5            0.00000   10  0.107655  0.553692     1     0.035810  0.388004
# 7            0.00236    2  0.056181  0.628503     0     0.477860  0.828990
# 9            0.00000    8  0.239664  0.704155     1     0.022837  0.201923
# 11           0.00000    5  0.079104  0.470372     1     0.022194  0.128929
# 13           0.00000    0  0.082992  0.508588     1     0.018012  0.312848
#
#      valence  lyrics_length
# 5   0.622108       0.248115
# 7   0.749817       0.076765
# 9   0.505914       0.086361
# 11  0.276667       0.193283
# 13  0.400188       0.047978
# R&B
#      popularity  acousticness  danceability  duration_ms    energy  \
# 57           59      0.161808      0.784450     0.316918  0.661219
# 61           77      0.403014      0.732761     0.311241  0.411166
# 181          48      0.706532      0.403937     0.424029  0.348652
# 211          49      0.219095      0.642582     0.548113  0.811452
# 213          55      0.012964      0.563400     0.505995  0.798344
#
#      instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 57           0.000045    4  0.050143  0.833858     1     0.180873  0.513261
# 61           0.000000    8  0.043799  0.770955     1     0.044602  0.391056
# 181          0.000258    8  0.089235  0.702815     1     0.057360  0.378476
# 211          0.000000    6  0.286738  0.861974     1     0.248419  0.292783
# 213          0.000027    0  0.056590  0.805804     1     0.021765  0.831071
#
#       valence  lyrics_length
# 57   0.560348       0.225497
# 61   0.443107       0.259767
# 181  0.139537       0.132282
# 211  0.693290       0.466073
# 213  0.451481       0.274160
# Indie
#      popularity  acousticness  danceability  duration_ms    energy  \
# 62           53      0.001647      0.563400     0.454659  0.925387
# 170          65      0.017285      0.703068     0.531049  0.814477
# 249          50      0.069245      0.523810     0.434672  0.786245
# 346          55      0.023718      0.528209     0.379325  0.894131
# 405          60      0.000003      0.431431     0.404095  0.882031
#
#      instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 62           0.024821    6  0.098445  0.898320     0     0.025732  0.449389
# 170          0.000640    0  0.079922  0.797668     1     0.016833  0.514324
# 249          0.000003   11  0.063140  0.846825     0     0.046317  0.215079
# 346          0.000000    1  0.115841  0.894798     1     0.048569  0.461954
# 405          0.677222    2  0.090258  0.851937     0     0.007612  0.524146
#
#       valence  lyrics_length
# 62   0.353083       0.185058
# 170  0.668167       0.210418
# 249  0.406469       0.198766
# 346  0.276667       0.145990
# 405  0.608500       0.102125
# Soul
#      popularity  acousticness  danceability  duration_ms    energy  \
# 179          42      0.841206      0.589794     0.226918  0.308321
# 232          54      0.168843      0.708567     0.619508  0.492836
# 237          54      0.069145      0.665677     0.601702  0.369826
# 242          55      0.176884      0.666777     0.599048  0.613830
# 243          42      0.125627      0.682173     0.620563  0.772129
#
#      instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 179          0.000038    1  0.088211  0.652255     1     0.018656  0.354631
# 232          0.000000    9  0.230454  0.512671     0     0.022301  0.410971
# 237          0.000000    7  0.460704  0.561017     0     0.017369  0.472166
# 242          0.000000    5  0.947810  0.646644     0     0.047818  0.430003
# 243          0.000000    5  0.145518  0.656526     0     0.027554  0.481685
#
#       valence  lyrics_length
# 179  0.527897       0.104181
# 232  0.773893       0.219328
# 237  0.598032       0.204935
# 242  0.605360       0.193283
# 243  0.547786       0.303633
# Rap
#     popularity  acousticness  danceability  duration_ms    energy  \
# 37          58      0.022110      0.973606     0.320171  0.883040
# 41          54      0.144723      0.854833     0.509932  0.663235
# 43          52      0.094471      0.844936     0.382921  0.730790
# 45          50      0.013969      0.824040     0.268838  0.567449
# 47          50      0.007245      0.902123     0.390398  0.751964
#
#     instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 37          0.000488    6  0.412607  0.787974     0     0.199099  0.318416
# 41          0.000000    1  0.115841  0.806240     1     0.224831  0.472736
# 43          0.000000    1  0.106631  0.778903     1     0.263429  0.197773
# 45          0.000065    7  0.258084  0.711387     1     0.225903  0.503311
# 47          0.000000    9  0.214081  0.765625     1     0.073764  0.462278
#
#      valence  lyrics_length
# 37  0.553020       0.326251
# 41  0.577096       0.520905
# 43  0.804250       0.395476
# 45  0.263059       0.250857
# 47  0.639904       0.331734
# Ska
#     popularity  acousticness  danceability  duration_ms    energy  \
# 66          35      0.677387      0.264269     0.316034  0.972776
# 67          33      0.615075      0.181788     0.184173  0.990925
# 68          35      0.015376      0.471022     0.112778  0.905222
# 69          29      0.445226      0.389640     0.169248  0.971768
# 71          59      0.003456      0.078412     0.415139  0.927404
#
#     instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 66          0.023187    2  0.275481  0.889748     1     0.168007  0.418877
# 67          0.161389    7  0.483217  0.891462     1     0.066581  0.655623
# 68          0.194076    9  0.019341  0.889654     1     0.027554  0.470127
# 69          0.036670    9  0.311298  0.898756     0     0.045138  0.375635
# 71          0.000449    7  0.074396  0.817119     1     0.055538  0.820304
#
#      valence  lyrics_length
# 66  0.511148       0.168609
# 67  0.766565       0.145305
# 68  0.866011       0.078136
# 69  0.859730       0.109664
# 71  0.490212       0.169294
# Hip-Hop
#     popularity  acousticness  danceability  duration_ms    energy  \
# 36          58      0.022110      0.973606     0.320171  0.883040
# 40          54      0.144723      0.854833     0.509932  0.663235
# 42          52      0.094471      0.844936     0.382921  0.730790
# 44          50      0.013969      0.824040     0.268838  0.567449
# 46          50      0.007245      0.902123     0.390398  0.751964
#
#     instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 36          0.000488    6  0.412607  0.787974     0     0.199099  0.318416
# 40          0.000000    1  0.115841  0.806240     1     0.224831  0.472736
# 42          0.000000    1  0.106631  0.778903     1     0.263429  0.197773
# 44          0.000065    7  0.258084  0.711387     1     0.225903  0.503311
# 46          0.000000    9  0.214081  0.765625     1     0.073764  0.462278
#
#      valence  lyrics_length
# 36  0.553020       0.326251
# 40  0.577096       0.520905
# 42  0.804250       0.395476
# 44  0.263059       0.250857
# 46  0.639904       0.331734
# Alternative
#      popularity  acousticness  danceability  duration_ms    energy  \
# 155          56      0.067939      0.645881     0.446526  0.941520
# 163          51      0.110552      0.778951     0.476231  0.654161
# 165          40      0.128642      0.681073     0.398959  0.830609
# 166          61      0.017285      0.703068     0.531049  0.814477
# 173          41      0.020502      0.577697     0.475033  0.965719
#
#      instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 155          0.000000    2  0.073373  0.854899     1     0.402809  0.274435
# 163          0.000000   10  0.061912  0.636389     0     0.239841  0.312334
# 165          0.002319    2  0.651044  0.849880     1     0.026697  0.302543
# 166          0.000640    0  0.079922  0.797668     1     0.016833  0.514324
# 173          0.003023    7  0.080025  0.936473     1     0.070977  0.487017
#
#       valence  lyrics_length
# 155  0.635717       0.434544
# 163  0.791688       0.459904
# 165  0.771799       0.170665
# 166  0.668167       0.210418
# 173  0.773893       0.076080
# Jazz
#     popularity  acousticness  danceability  duration_ms    energy  \
# 6           32      0.933668      0.776751     0.284247  0.073090
# 8           44      0.856281      0.600792     0.247265  0.351677
# 10          46      0.920603      0.585395     0.308645  0.287147
# 12          54      0.975879      0.320356     0.840229  0.105657
# 14          43      0.897487      0.601892     0.379325  0.124815
#
#     instrumentalness  key  liveness  loudness  mode  speechiness     tempo  \
# 6            0.00000   10  0.108678  0.559210     1     0.036453  0.386515
# 8            0.00236    2  0.056181  0.628503     0     0.477860  0.828990
# 10           0.00000    8  0.239664  0.704155     1     0.022837  0.201923
# 12           0.00000    5  0.079104  0.470372     1     0.022194  0.128929
# 14           0.00000    0  0.085141  0.599451     1     0.015653  0.312724
#
#      valence  lyrics_length
# 6   0.602219       0.248115
# 8   0.749817       0.076765
# 10  0.505914       0.086361
# 12  0.276667       0.193283
# 14  0.367738       0.047978
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)
# /tmp/ipykernel_125909/521243162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['genre'], inplace=True)

# %%
# See flops and bops for each genre
for genre in dict_of_genres.values():
    popularity_threshold = genre['popularity'].median()
    print(popularity_threshold)

    genre['flop_or_bop'] = np.where(
        genre['popularity'] < popularity_threshold, "flop", "bop"
    )

    # turn flop_or_bop into a int value for model training
    genre['flop_or_bop'] = np.where(
        genre['flop_or_bop'] == "flop", 0, 1
    )

    print(genre['flop_or_bop'].value_counts())

    genre.drop(columns=['popularity'], inplace=True)
# Out:
# 45.0
# flop_or_bop
# 1    682
# 0    598
# Name: count, dtype: int64
# 50.0
# flop_or_bop
# 1    643
# 0    631
# Name: count, dtype: int64
# 59.0
# flop_or_bop
# 1    691
# 0    552
# Name: count, dtype: int64
# 54.5
# flop_or_bop
# 1    599
# 0    599
# Name: count, dtype: int64
# 48.0
# flop_or_bop
# 1    616
# 0    499
# Name: count, dtype: int64
# 56.0
# flop_or_bop
# 1    478
# 0    466
# Name: count, dtype: int64
# 35.0
# flop_or_bop
# 1    479
# 0    443
# Name: count, dtype: int64
# 52.0
# flop_or_bop
# 1    391
# 0    386
# Name: count, dtype: int64
# 54.0
# flop_or_bop
# 1    384
# 0    382
# Name: count, dtype: int64
# 46.0
# flop_or_bop
# 1    365
# 0    360
# Name: count, dtype: int64
# 60.0
# flop_or_bop
# 1    354
# 0    336
# Name: count, dtype: int64
# 28.0
# flop_or_bop
# 1    334
# 0    300
# Name: count, dtype: int64
# 56.0
# flop_or_bop
# 1    292
# 0    240
# Name: count, dtype: int64
# 44.0
# flop_or_bop
# 1    209
# 0    197
# Name: count, dtype: int64
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)
# /tmp/ipykernel_125909/4212895266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre['flop_or_bop'] = np.where(
# /tmp/ipykernel_125909/4212895266.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre.drop(columns=['popularity'], inplace=True)

# %%
# split
from sklearn.model_selection import train_test_split
# models
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc


# Split the data into training and test sets
for genre_name, genre in dict_of_genres.items():
    print(genre_name)
    X_train, X_test, y_train, y_test = train_test_split(
    genre.drop(columns=['flop_or_bop']), 
    genre['flop_or_bop'], 
    test_size=0.2, 
    random_state=1337,
    stratify=genre['flop_or_bop']
)
    print("starting")
    print(X_train.value_counts())
    print(y_train.value_counts())
    print("Starting training for a genre...")
    learning_rates = [0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 1]
    for learning_rate in learning_rates:
        gb = GradientBoostingClassifier(n_estimators=1,
                                        learning_rate = learning_rate,
                                        max_depth = 3, 
                                        random_state = 1337)
        gb.fit(X_train, y_train)
        print("Learning rate: ", learning_rate)
        print("Accuracy score (training): {0:.3f}".format(gb.score(X_train, y_train)))
        print("Accuracy score (validation): {0:.3f}".format(gb.score(X_test, y_test)))
    input("Press Enter to continue...")
# Out:
# country
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 0.865326      0.399538      0.488788     0.367810  0.015117          0    0.055772  0.644151  1     0.008256     0.212865  0.272480  0.094585         1
#               0.418234      0.433058     0.377892  0.000051          0    0.096398  0.684486  1     0.013080     0.317348  0.359364  0.200822         1
#               0.588695      0.208370     0.341594  0.003156          7    0.113795  0.589321  1     0.018870     0.414475  0.489166  0.096642         1
# 0.866332      0.387441      0.238646     0.082366  0.000000          7    0.075829  0.350924  1     0.012008     0.237316  0.540458  0.061686         1
#               0.442428      0.333954     0.272023  0.000004          2    0.918133  0.632056  1     0.348129     0.203326  0.383440  0.255655         1
#                                                                                                                                                      ..
# 0.000504      0.559001      0.384691     0.816493  0.000013          8    0.067131  0.724260  1     0.020585     0.387568  0.476604  0.194654         1
# 0.000557      0.535907      0.286843     0.876990  0.000000          6    0.079922  0.828434  1     0.010078     0.374710  0.361457  0.150788         1
# 0.000590      0.409436      0.352445     0.794311  0.000000          7    0.381907  0.829027  1     0.012437     0.235713  0.212813  0.204935         1
# 0.000602      0.325855      0.363432     0.706591  0.005087          4    0.268318  0.868084  1     0.009864     0.580199  0.204438  0.152159         1
# 0.000811      0.560101      0.413221     0.903205  0.000000          1    0.279574  0.856706  1     0.033773     0.462283  0.739349  0.276217         1
# Name: count, Length: 1024, dtype: int64
# flop_or_bop
# 1    546
# 0    478
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.533
# Accuracy score (validation): 0.531
# Learning rate:  0.1
# Accuracy score (training): 0.579
# Accuracy score (validation): 0.531
# Learning rate:  0.25
# Accuracy score (training): 0.579
# Accuracy score (validation): 0.531
# Learning rate:  0.5
# Accuracy score (training): 0.623
# Accuracy score (validation): 0.566
# Learning rate:  0.75
# Accuracy score (training): 0.623
# Accuracy score (validation): 0.566
# Learning rate:  0.9
# Accuracy score (training): 0.623
# Accuracy score (validation): 0.566
# Learning rate:  1
# Accuracy score (training): 0.623
# Accuracy score (validation): 0.574
# Alternative
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 9.879397e-01  0.496316      0.076821     0.124815  0.004229          0    0.103561  0.585954  1     0.476788     0.348230  0.818905  0.098012         1
# 5.728649e-07  0.074013      0.477745     0.951603  0.898876          4    0.068154  0.831115  1     0.101533     0.196874  0.179315  0.095271         1
# 2.311560e-06  0.414935      0.311840     0.894131  0.021553          6    0.073373  0.785169  0     0.031521     0.298393  0.585471  0.127485         1
# 3.547742e-06  0.467722      0.354243     0.973785  0.026864          6    0.191568  0.872822  1     0.147636     0.565173  0.238983  0.158328         1
# 3.678396e-06  0.094908      0.454716     0.908247  0.627171          9    0.054748  0.755868  1     0.101533     0.286999  0.040825  0.068540         1
#                                                                                                                                                      ..
# 1.286433e-05  0.317057      0.449895     0.974793  0.000000          8    0.177241  0.883327  1     0.052857     0.698649  0.342615  0.163811         1
# 1.316584e-05  0.446827      0.400727     0.996975  0.000000          11   0.246828  0.890184  0     0.168007     0.194999  0.065215  0.209047         1
# 1.326634e-05  0.524909      0.597963     0.982859  0.471910          0    0.360418  0.844425  1     0.039563     0.487828  0.118601  0.050720         1
# 1.417087e-05  0.230177      0.369624     0.910263  0.000044          7    0.117888  0.870920  1     0.067653     0.259132  0.122789  0.069225         1
# 1.457288e-05  0.216980      0.550709     0.978826  0.003054          2    0.318461  0.810760  1     0.048890     0.507389  0.362504  0.168609         1
# Name: count, Length: 1019, dtype: int64
# flop_or_bop
# 1    514
# 0    505
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.599
# Accuracy score (validation): 0.537
# Learning rate:  0.1
# Accuracy score (training): 0.599
# Accuracy score (validation): 0.537
# Learning rate:  0.25
# Accuracy score (training): 0.599
# Accuracy score (validation): 0.537
# Learning rate:  0.5
# Accuracy score (training): 0.599
# Accuracy score (validation): 0.537
# Learning rate:  0.75
# Accuracy score (training): 0.599
# Accuracy score (validation): 0.537
# Learning rate:  0.9
# Accuracy score (training): 0.599
# Accuracy score (validation): 0.537
# Learning rate:  1
# Accuracy score (training): 0.599
# Accuracy score (validation): 0.537
# rock
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 0.983920      0.377543      0.458312     0.145989  0.000093          0    0.087188  0.551230  1     0.018441     0.119806  0.367738  0.155586         1
# 0.000008      0.342351      0.333868     0.735831  0.000000          1    0.051985  0.819893  1     0.007934     0.718554  0.558254  0.147361         1
# 0.804020      0.366546      0.499602     0.246816  0.000000          0    0.084118  0.560955  1     0.008363     0.717418  0.098712  0.135024         1
# 0.814070      0.716265      0.464503     0.314371  0.000006          0    0.126074  0.638571  1     0.006111     0.287795  0.460902  0.220699         1
# 0.817085      0.611789      0.326592     0.300255  0.000000          3    0.083095  0.513637  0     0.015975     0.347747  0.838794  0.252913         1
#                                                                                                                                                      ..
# 0.000012      0.374244      0.362234     0.970760  0.000003          2    0.174171  0.843085  0     0.047711     0.190519  0.465090  0.184373         1
#               0.419334      0.393508     0.780195  0.209397          1    0.150634  0.851220  1     0.016511     0.173748  0.356223  0.135709         1
# 0.000017      0.511712      0.379554     0.763055  0.000027          5    0.128121  0.789502  1     0.021014     0.333416  0.659793  0.132282         1
#               0.378643      0.585294     0.757005  0.002584          5    0.295948  0.856738  1     0.035917     0.379025  0.523710  0.139822         1
# 0.000018      0.483119      0.416080     0.905222  0.781410          11   0.372698  0.806209  0     0.031629     0.437965  0.578143  0.146676         1
# Name: count, Length: 994, dtype: int64
# flop_or_bop
# 1    553
# 0    441
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.556
# Accuracy score (validation): 0.554
# Learning rate:  0.1
# Accuracy score (training): 0.556
# Accuracy score (validation): 0.554
# Learning rate:  0.25
# Accuracy score (training): 0.589
# Accuracy score (validation): 0.562
# Learning rate:  0.5
# Accuracy score (training): 0.589
# Accuracy score (validation): 0.562
# Learning rate:  0.75
# Accuracy score (training): 0.589
# Accuracy score (validation): 0.562
# Learning rate:  0.9
# Accuracy score (training): 0.589
# Accuracy score (validation): 0.562
# Learning rate:  1
# Accuracy score (training): 0.589
# Accuracy score (validation): 0.562
# children
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 9.879397e-01  0.496316      0.076821     0.124815  0.004229          0    0.103561  0.585954  1     0.476788     0.348230  0.818905  0.098012         1
# 5.728649e-07  0.074013      0.477745     0.951603  0.898876          4    0.068154  0.831115  1     0.101533     0.196874  0.179315  0.095271         1
# 1.668343e-06  0.218080      0.311840     0.896147  0.021655          9    0.064163  0.785262  1     0.092956     0.792996  0.558254  0.127485         1
# 3.547742e-06  0.467722      0.354243     0.973785  0.026864          6    0.191568  0.872822  1     0.147636     0.565173  0.238983  0.158328         1
# 3.678396e-06  0.094908      0.454716     0.908247  0.627171          9    0.054748  0.755868  1     0.101533     0.286999  0.040825  0.068540         1
#                                                                                                                                                      ..
# 1.809047e-05  0.575498      0.403787     0.990925  0.000000          6    0.133238  0.862754  0     0.059505     0.380135  0.534178  0.159013         1
# 1.829148e-05  0.254371      0.369453     0.904214  0.000000          11   0.086165  0.855023  0     0.055002     0.689109  0.274573  0.167238         1
# 1.849248e-05  0.238975      0.340747     0.987901  0.000125          0    0.103561  0.841838  1     0.082449     0.244574  0.197111  0.080877         1
# 1.869349e-05  0.549104      0.390683     0.979834  0.003922          11   0.080639  0.892210  0     0.131554     0.328669  0.280854  0.126114         1
# 1.989952e-05  0.465523      0.415222     0.987901  0.000000          4    0.253991  0.887909  1     0.055216     0.439501  0.251544  0.145305         1
# Name: count, Length: 958, dtype: int64
# flop_or_bop
# 0    479
# 1    479
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.597
# Accuracy score (validation): 0.533
# Learning rate:  0.1
# Accuracy score (training): 0.597
# Accuracy score (validation): 0.533
# Learning rate:  0.25
# Accuracy score (training): 0.597
# Accuracy score (validation): 0.533
# Learning rate:  0.5
# Accuracy score (training): 0.597
# Accuracy score (validation): 0.533
# Learning rate:  0.75
# Accuracy score (training): 0.597
# Accuracy score (validation): 0.533
# Learning rate:  0.9
# Accuracy score (training): 0.597
# Accuracy score (validation): 0.533
# Learning rate:  1
# Accuracy score (training): 0.597
# Accuracy score (validation): 0.533
# folk
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 0.994975      0.273067      0.572911     0.138931  0.280899          0    0.058535  0.383685  1     0.008577     0.641029  0.304930  0.105552         1
# 0.000004      0.284065      0.411828     0.622904  0.000286          11   0.294924  0.829089  1     0.012223     0.434041  0.445200  0.061686         1
# 0.000021      0.369845      0.435853     0.968743  0.005812          1    0.088211  0.851064  1     0.013616     0.608251  0.794829  0.248801         1
# 0.000023      0.210382      0.406634     0.704575  0.576098          10   0.109701  0.684891  1     0.043315     0.690368  0.693290  0.256340         1
# 0.000088      0.451226      0.433771     0.807419  0.000032          6    0.309251  0.836445  1     0.014474     0.472824  0.484979  0.172721         1
#                                                                                                                                                      ..
# 0.001708      0.251072      0.462736     0.880015  0.000029          1    0.631600  0.821140  1     0.027233     0.648487  0.413797  0.141193         1
# 0.001718      0.534807      0.582383     0.864891  0.000459          0    0.448424  0.818553  1     0.008470     0.400821  0.605360  0.261138         1
# 0.001888      0.345651      0.649242     0.897156  0.080695          11   0.104585  0.811165  1     0.030878     0.439886  0.416937  0.154901         1
# 0.001898      0.329154      0.656747     0.901189  0.207354          9    0.263201  0.802625  1     0.012115     0.299857  0.625249  0.093215         1
# 0.001959      0.365446      0.437082     0.610805  0.059346          11   0.245804  0.767557  1     0.015975     0.636822  0.396001  0.224812         1
# Name: count, Length: 892, dtype: int64
# flop_or_bop
# 1    493
# 0    399
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.553
# Accuracy score (validation): 0.552
# Learning rate:  0.1
# Accuracy score (training): 0.553
# Accuracy score (validation): 0.552
# Learning rate:  0.25
# Accuracy score (training): 0.572
# Accuracy score (validation): 0.565
# Learning rate:  0.5
# Accuracy score (training): 0.578
# Accuracy score (validation): 0.547
# Learning rate:  0.75
# Accuracy score (training): 0.603
# Accuracy score (validation): 0.511
# Learning rate:  0.9
# Accuracy score (training): 0.603
# Accuracy score (validation): 0.511
# Learning rate:  1
# Accuracy score (training): 0.603
# Accuracy score (validation): 0.511
# dance
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 0.917588      0.454525      0.274858     0.421248  0.105209          9    0.351208  0.575699  1     0.073979     0.503126  0.537318  0.040439         1
# 0.000003      0.431431      0.404095     0.882031  0.677222          2    0.090258  0.851937  0     0.007612     0.524146  0.608500  0.102125         1
# 0.000012      0.389640      0.348222     0.949586  0.001941          8    0.204871  0.905863  1     0.183017     0.611230  0.393908  0.164496         1
# 0.000028      0.363246      0.430434     0.981851  0.043105          1    0.158821  0.842274  0     0.061756     0.626846  0.317492  0.161755         1
# 0.000049      0.624986      0.448782     0.773137  0.000000          1    0.208964  0.832424  0     0.009542     0.349370  0.056736  0.212474         1
#                                                                                                                                                      ..
# 0.000463      0.709667      0.074482     0.320421  0.000000          2    0.102538  0.617531  0     0.025196     0.415867  0.294462  0.029472         1
# 0.000484      0.444628      0.287271     0.837667  0.000011          2    0.151658  0.900440  0     0.018870     0.533993  0.767612  0.187114         1
# 0.000487      0.599692      0.353643     0.731798  0.000002          6    0.301064  0.855802  0     0.009542     0.524367  0.563488  0.257711         1
# 0.000518      0.314858      0.388485     0.907238  0.000000          5    0.145518  0.870453  0     0.029377     0.757111  0.152099  0.148732         1
# 0.000534      0.443528      0.382694     0.954627  0.000028          4    0.301064  0.843147  1     0.065402     0.605539  0.758191  0.178890         1
# Name: count, Length: 755, dtype: int64
# flop_or_bop
# 1    382
# 0    373
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.546
# Accuracy score (validation): 0.487
# Learning rate:  0.1
# Accuracy score (training): 0.581
# Accuracy score (validation): 0.566
# Learning rate:  0.25
# Accuracy score (training): 0.581
# Accuracy score (validation): 0.566
# Learning rate:  0.5
# Accuracy score (training): 0.581
# Accuracy score (validation): 0.566
# Learning rate:  0.75
# Accuracy score (training): 0.581
# Accuracy score (validation): 0.566
# Learning rate:  0.9
# Accuracy score (training): 0.581
# Accuracy score (validation): 0.566
# Learning rate:  1
# Accuracy score (training): 0.581
# Accuracy score (validation): 0.566
# blues
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 0.998995      0.743759      0.226433     0.334537  0.306435          7    0.075113  0.682148  1     0.044816     0.289727  0.410656  0.084990         1
# 0.920603      0.585395      0.308645     0.287147  0.000000          8    0.239664  0.704155  1     0.022837     0.201923  0.505914  0.086361         1
# 0.921608      0.586495      0.381523     0.087206  0.000000          0    0.082992  0.508588  1     0.018012     0.312848  0.400188  0.047978         1
# 0.922613      0.274167      0.555961     0.461580  0.846782          0    0.099468  0.489885  1     0.027018     0.422699  0.180362  0.000000         1
#               0.664577      0.594484     0.235725  0.000074          2    0.097421  0.555469  0     0.059505     0.208041  0.542552  0.074709         1
#                                                                                                                                                      ..
# 0.000041      0.366546      0.665879     0.973785  0.045659          0    0.051781  0.866837  1     0.032272     0.440282  0.481838  0.125428         1
# 0.000045      0.341252      0.480741     0.668277  0.822268          4    0.157798  0.632711  0     0.025839     0.725745  0.602219  0.139136         1
# 0.000055      0.314858      0.498776     0.673318  0.008815          5    0.362464  0.550295  1     0.014152     0.316181  0.842981  0.177519         1
# 0.000057      0.502914      0.514953     0.909255  0.149132          9    0.104585  0.813005  1     0.045674     0.337921  0.548833  0.202879         1
# 0.000074      0.324755      0.544545     0.876990  0.000158          9    0.260131  0.864188  1     0.019299     0.383849  0.376112  0.153530         1
# Name: count, Length: 737, dtype: int64
# flop_or_bop
# 1    383
# 0    354
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.520
# Accuracy score (validation): 0.519
# Learning rate:  0.1
# Accuracy score (training): 0.581
# Accuracy score (validation): 0.541
# Learning rate:  0.25
# Accuracy score (training): 0.615
# Accuracy score (validation): 0.573
# Learning rate:  0.5
# Accuracy score (training): 0.615
# Accuracy score (validation): 0.573
# Learning rate:  0.75
# Accuracy score (training): 0.615
# Accuracy score (validation): 0.573
# Learning rate:  0.9
# Accuracy score (training): 0.615
# Accuracy score (validation): 0.573
# Learning rate:  1
# Accuracy score (training): 0.615
# Accuracy score (validation): 0.562
# rnb
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 0.987940      0.496316      0.076821     0.124815  0.004229          0    0.103561  0.585954  1     0.476788     0.348230  0.818905  0.098012         1
# 0.000081      0.602991      0.524201     0.690459  0.000014          0    0.695047  0.736261  1     0.068618     0.319171  0.165707  0.230980         1
# 0.000298      0.811943      0.482511     0.492836  0.000000          7    0.052088  0.762133  1     0.030342     0.463716  0.340521  0.326936         1
# 0.000387      0.610690      0.548740     0.402091  0.000000          8    0.329718  0.664038  1     0.022408     0.667874  0.299696  0.153530         1
# 0.000480      0.696470      0.400842     0.576523  0.000000          0    0.037659  0.826626  1     0.010936     0.261670  0.726787  0.130912         1
#                                                                                                                                                      ..
# 0.002290      0.560101      0.490044     0.881023  0.000000          7    0.659230  0.884168  0     0.281655     0.642518  0.660840  0.342015         1
# 0.002753      0.940614      0.339662     0.626937  0.006159          11   0.386001  0.794364  0     0.027233     0.369666  0.352036  0.357779         1
# 0.002853      0.708567      0.386944     0.545267  0.000075          4    0.029267  0.834357  0     0.007612     0.313233  0.705852  0.201508         1
# 0.003295      0.885626      0.590259     0.416207  0.000003          1    0.071531  0.689099  1     0.155141     0.429659  0.350989  0.286498         1
# 0.003657      0.775652      0.523944     0.548291  0.000000          0    0.026914  0.756117  1     0.042136     0.323039  0.800063  0.265250         1
# Name: count, Length: 621, dtype: int64
# flop_or_bop
# 1    312
# 0    309
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.588
# Accuracy score (validation): 0.615
# Learning rate:  0.1
# Accuracy score (training): 0.589
# Accuracy score (validation): 0.615
# Learning rate:  0.25
# Accuracy score (training): 0.589
# Accuracy score (validation): 0.615
# Learning rate:  0.5
# Accuracy score (training): 0.589
# Accuracy score (validation): 0.615
# Learning rate:  0.75
# Accuracy score (training): 0.589
# Accuracy score (validation): 0.615
# Learning rate:  0.9
# Accuracy score (training): 0.589
# Accuracy score (validation): 0.615
# Learning rate:  1
# Accuracy score (training): 0.589
# Accuracy score (validation): 0.615
# indie
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 0.994975      0.273067      0.572911     0.138931  0.280899          0    0.058535  0.383685  1     0.008577     0.641029  0.304930  0.105552         1
# 0.000003      0.431431      0.404095     0.882031  0.677222          2    0.090258  0.851937  0     0.007612     0.524146  0.608500  0.102125         1
# 0.000014      0.296162      0.359522     0.913288  0.022983          5    0.114818  0.893239  1     0.015439     0.872340  0.823092  0.071967         1
# 0.000021      0.369845      0.435853     0.968743  0.005812          1    0.088211  0.851064  1     0.013616     0.608251  0.794829  0.248801         1
# 0.903517      0.214781      0.322284     0.405116  0.002993          7    0.092305  0.647018  0     0.015010     0.553451  0.049932  0.115833         1
#                                                                                                                                                      ..
# 0.000089      0.543605      0.369309     0.916313  0.003483          0    0.335858  0.824226  1     0.018763     0.400918  0.461949  0.212474         1
#               0.458924      0.296687     0.930429  0.000001          0    0.094351  0.822231  1     0.041921     0.369872  0.371925  0.111720         1
# 0.000096      0.533707      0.296159     0.596689  0.693565          11   0.215104  0.795736  1     0.012973     0.401432  0.581283  0.119945         1
# 0.000105      0.449027      0.410201     0.978826  0.000000          10   0.082481  0.863003  1     0.162646     0.590719  0.732021  0.202193         1
# 0.000111      0.652480      0.332030     0.893123  0.028294          10   0.047073  0.898974  1     0.033773     0.493047  0.880666  0.161755         1
# Name: count, Length: 612, dtype: int64
# flop_or_bop
# 1    307
# 0    305
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.637
# Accuracy score (validation): 0.500
# Learning rate:  0.1
# Accuracy score (training): 0.637
# Accuracy score (validation): 0.500
# Learning rate:  0.25
# Accuracy score (training): 0.637
# Accuracy score (validation): 0.500
# Learning rate:  0.5
# Accuracy score (training): 0.637
# Accuracy score (validation): 0.500
# Learning rate:  0.75
# Accuracy score (training): 0.637
# Accuracy score (validation): 0.500
# Learning rate:  0.9
# Accuracy score (training): 0.637
# Accuracy score (validation): 0.500
# Learning rate:  1
# Accuracy score (training): 0.637
# Accuracy score (validation): 0.500
# soul
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 0.997990      0.351149      0.548911     0.016223  0.933606          0    0.094351  0.154733  0     0.016940     0.123356  0.120695  0.057574         1
# 0.000081      0.602991      0.524201     0.690459  0.000014          0    0.695047  0.736261  1     0.068618     0.319171  0.165707  0.230980         1
# 0.000363      0.675575      0.391539     0.702558  0.072421          10   0.123005  0.718525  1     0.011365     0.470414  0.816811  0.163125         1
# 0.000387      0.610690      0.548740     0.402091  0.000000          8    0.329718  0.664038  1     0.022408     0.667874  0.299696  0.153530         1
# 0.874372      0.411635      0.330416     0.148005  0.000010          1    0.206918  0.537795  1     0.026697     0.182506  0.269339  0.117204         1
#                                                                                                                                                      ..
# 0.002461      0.402837      0.306361     0.911272  0.000000          1    0.320508  0.836695  1     0.035488     0.575432  0.455668  0.161755         1
# 0.002512      0.664577      0.739757     0.444439  0.029009          10   0.145518  0.695708  1     0.018227     0.421158  0.204438  0.144620         1
# 0.003265      0.798746      0.362290     0.726757  0.234934          5    0.080946  0.824850  0     0.007720     0.349129  0.946614  0.126114         1
# 0.003346      0.882327      0.295975     0.927404  0.000071          10   0.820917  0.850971  0     0.094028     0.366183  0.684916  0.207676         1
# 0.003657      0.775652      0.523944     0.548291  0.000000          0    0.026914  0.756117  1     0.042136     0.323039  0.800063  0.265250         1
# Name: count, Length: 580, dtype: int64
# flop_or_bop
# 1    292
# 0    288
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.619
# Accuracy score (validation): 0.510
# Learning rate:  0.1
# Accuracy score (training): 0.619
# Accuracy score (validation): 0.510
# Learning rate:  0.25
# Accuracy score (training): 0.619
# Accuracy score (validation): 0.510
# Learning rate:  0.5
# Accuracy score (training): 0.626
# Accuracy score (validation): 0.538
# Learning rate:  0.75
# Accuracy score (training): 0.626
# Accuracy score (validation): 0.538
# Learning rate:  0.9
# Accuracy score (training): 0.626
# Accuracy score (validation): 0.538
# Learning rate:  1
# Accuracy score (training): 0.626
# Accuracy score (validation): 0.538
# rap
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 0.763819      0.732761      0.550140     0.349661  0.000000          1    0.115841  0.684486  1     0.213037     0.486688  0.632576  0.335846         1
# 0.000010      0.528209      0.401583     0.986892  0.000815          2    0.301064  0.901531  0     0.079876     0.359793  0.244216  0.122687         1
# 0.000011      0.535907      0.372250     0.969752  0.108274          1    0.087188  0.898413  1     0.028627     0.323815  0.331100  0.259767         1
# 0.000012      0.419334      0.393508     0.780195  0.209397          1    0.150634  0.851220  1     0.016511     0.173748  0.356223  0.135709         1
# 0.000013      0.576597      0.260534     0.889089  0.620020          11   0.053930  0.849537  0     0.028412     0.526616  0.842981  0.061686         1
#                                                                                                                                                      ..
# 0.000039      0.498515      0.418563     0.950594  0.000004          2    0.018215  0.862411  1     0.032486     0.277979  0.452528  0.161755         1
# 0.000049      0.292863      0.434657     0.939503  0.006639          2    0.325624  0.932982  0     0.021443     0.760013  0.311211  0.227553         1
# 0.000051      0.445727      0.375246     0.986892  0.000094          9    0.278551  0.900689  1     0.044066     0.626271  0.385533  0.227553         1
# 0.000057      0.431431      0.372164     0.968743  0.093565          8    0.049120  0.876781  1     0.179801     0.277517  0.271433  0.203564         1
# 0.000068      0.296162      0.335439     0.748939  0.000001          5    0.077466  0.822387  1     0.022837     0.760008  0.238983  0.261138         1
# Name: count, Length: 552, dtype: int64
# flop_or_bop
# 1    283
# 0    269
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.547
# Accuracy score (validation): 0.500
# Learning rate:  0.1
# Accuracy score (training): 0.547
# Accuracy score (validation): 0.500
# Learning rate:  0.25
# Accuracy score (training): 0.605
# Accuracy score (validation): 0.500
# Learning rate:  0.5
# Accuracy score (training): 0.605
# Accuracy score (validation): 0.500
# Learning rate:  0.75
# Accuracy score (training): 0.605
# Accuracy score (validation): 0.500
# Learning rate:  0.9
# Accuracy score (training): 0.605
# Accuracy score (validation): 0.500
# Learning rate:  1
# Accuracy score (training): 0.605
# Accuracy score (validation): 0.500
# ska
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 0.857286      0.355548      0.312240     0.397050  0.000000          2    0.041854  0.687198  1     0.008041     0.206033  0.414844  0.069911         1
# 0.000001      0.270868      0.171007     0.950594  0.016037          4    0.140401  0.724510  0     0.087595     0.304942  0.397048  0.057574         1
# 0.000004      0.365446      0.163884     0.940512  0.002104          9    0.023230  0.864063  0     0.048461     0.429443  0.712132  0.082934         1
# 0.000006      0.301661      0.034675     0.723732  0.084168          2    0.355301  0.723793  1     0.027126     0.539803  0.522663  0.043180         1
#               0.310459      0.266325     0.818510  0.008611          9    0.019546  0.683832  1     0.033773     0.277625  0.942426  0.103496         1
#                                                                                                                                                      ..
# 0.000052      0.309359      0.203606     0.913288  0.000106          7    0.157798  0.731929  1     0.089739     0.284883  0.275620  0.109664         1
# 0.000053      0.260970      0.199355     0.996975  0.000000          2    0.392141  0.831645  1     0.154069     0.527536  0.129069  0.137766         1
#               0.291763      0.203490     0.976810  0.000466          0    0.156774  0.890465  1     0.041064     0.315704  0.606406  0.088417         1
# 0.000054      0.397339      0.050741     0.958661  0.000015          0    0.183381  0.839157  1     0.016082     0.393485  0.938239  0.054832         1
# 0.000059      0.361047      0.164940     0.948578  0.000372          9    0.200778  0.867492  1     0.067439     0.258105  0.436826  0.071967         1
# Name: count, Length: 507, dtype: int64
# flop_or_bop
# 1    267
# 0    240
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.527
# Accuracy score (validation): 0.528
# Learning rate:  0.1
# Accuracy score (training): 0.602
# Accuracy score (validation): 0.559
# Learning rate:  0.25
# Accuracy score (training): 0.679
# Accuracy score (validation): 0.567
# Learning rate:  0.5
# Accuracy score (training): 0.684
# Accuracy score (validation): 0.567
# Learning rate:  0.75
# Accuracy score (training): 0.684
# Accuracy score (validation): 0.567
# Learning rate:  0.9
# Accuracy score (training): 0.684
# Accuracy score (validation): 0.567
# Learning rate:  1
# Accuracy score (training): 0.684
# Accuracy score (validation): 0.567
# hiphop
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 0.989950      0.654679      0.119962     0.427298  0.000000          7    0.133238  0.637075  1     0.556127     0.233684  0.945567  0.111035         1
# 0.000361      0.837237      0.522660     0.655169  0.001502          0    0.131191  0.779496  1     0.193739     0.298280  0.084057  0.567512         1
# 0.000629      0.802046      0.459281     0.598705  0.000032          7    0.090258  0.829369  0     0.208749     0.668526  0.251544  0.505826         1
# 0.001074      0.693171      0.630353     0.547283  0.006762          0    0.071838  0.717933  1     0.207677     0.679339  0.180362  0.636737         1
# 0.001316      0.695370      0.520605     0.717682  0.000015          7    0.053827  0.843085  1     0.027983     0.472300  0.335287  0.501028         1
#                                                                                                                                                      ..
# 0.003496      0.953811      0.555019     0.648111  0.000000          7    0.295948  0.894704  1     0.068082     0.381316  0.652465  0.509938         1
# 0.003527      0.656879      0.420617     0.925387  0.000000          7    0.130168  0.836165  1     0.392087     0.268003  0.772846  0.446196         1
# 0.003657      0.775652      0.523944     0.548291  0.000000          0    0.026914  0.756117  1     0.042136     0.323039  0.800063  0.265250         1
# 0.003818      0.436930      0.516903     0.899172  0.000000          2    0.109701  0.891712  1     0.201244     0.710766  0.424265  0.527759         1
# 0.004190      0.960409      0.414454     0.745914  0.000000          1    0.192591  0.852654  1     0.395304     0.408870  0.737255  0.533927         1
# Name: count, Length: 425, dtype: int64
# flop_or_bop
# 1    233
# 0    192
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.548
# Accuracy score (validation): 0.551
# Learning rate:  0.1
# Accuracy score (training): 0.593
# Accuracy score (validation): 0.570
# Learning rate:  0.25
# Accuracy score (training): 0.600
# Accuracy score (validation): 0.570
# Learning rate:  0.5
# Accuracy score (training): 0.600
# Accuracy score (validation): 0.570
# Learning rate:  0.75
# Accuracy score (training): 0.638
# Accuracy score (validation): 0.505
# Learning rate:  0.9
# Accuracy score (training): 0.638
# Accuracy score (validation): 0.505
# Learning rate:  1
# Accuracy score (training): 0.638
# Accuracy score (validation): 0.505
# Jazz
# starting
# acousticness  danceability  duration_ms  energy    instrumentalness  key  liveness  loudness  mode  speechiness  tempo     valence   lyrics_length
# 9.979899e-01  0.292863      0.625644     0.035179  0.536261          6    0.079411  0.269692  1     0.021765     0.075902  0.154192  0.087046         1
# 6.532670e-07  0.405037      0.733279     0.954627  0.591420          9    0.603971  0.816153  1     0.039241     0.318277  0.271433  0.109664         1
# 1.015076e-06  0.182888      0.864941     0.980843  0.850868          1    0.276504  0.818927  1     0.094028     0.472187  0.347849  0.112406         1
# 3.115581e-06  0.222479      0.521547     0.986892  0.006374          11   0.035510  0.826845  1     0.085451     0.350043  0.200251  0.090473         1
# 9.507537e-01  0.502914      0.355270     0.194386  0.000002          5    0.090258  0.642499  1     0.022622     0.281873  0.528944  0.110350         1
#                                                                                                                                                      ..
# 3.608044e-04  0.601892      0.383892     0.808427  0.833504          7    0.169054  0.781678  0     0.024445     0.626656  0.624202  0.044551         1
# 4.572869e-04  0.619488      0.619451     0.842709  0.000777          11   0.163938  0.823603  1     0.050606     0.410596  0.717366  0.432488         1
# 2.511560e-03  0.664577      0.739757     0.444439  0.029009          10   0.145518  0.695708  1     0.018227     0.421158  0.204438  0.144620         1
# 3.225129e-03  0.685472      0.386546     0.580556  0.671093          7    0.063140  0.658957  1     0.027769     0.572601  0.474511  0.156271         1
# 6.843223e-03  0.736061      0.770689     0.423265  0.005792          5    0.145518  0.658302  0     0.039241     0.227001  0.497540  0.253598         1
# Name: count, Length: 324, dtype: int64
# flop_or_bop
# 1    167
# 0    157
# Name: count, dtype: int64
# Starting training for a genre...
# Learning rate:  0.05
# Accuracy score (training): 0.602
# Accuracy score (validation): 0.524
# Learning rate:  0.1
# Accuracy score (training): 0.602
# Accuracy score (validation): 0.524
# Learning rate:  0.25
# Accuracy score (training): 0.602
# Accuracy score (validation): 0.524
# Learning rate:  0.5
# Accuracy score (training): 0.602
# Accuracy score (validation): 0.524
# Learning rate:  0.75
# Accuracy score (training): 0.602
# Accuracy score (validation): 0.524
# Learning rate:  0.9
# Accuracy score (training): 0.602
# Accuracy score (validation): 0.524
# Learning rate:  1
# Accuracy score (training): 0.602
# Accuracy score (validation): 0.524
